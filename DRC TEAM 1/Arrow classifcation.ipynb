# %%
import cv2
import os
import logging
from concurrent.futures import ThreadPoolExecutor

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Function to split video into frames
def split_video_to_frames(video_path, output_dir):
    if not os.path.exists(video_path):
        logging.error(f"Video file {video_path} does not exist.")
        return

    try:
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame_path = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
            cv2.imwrite(frame_path, frame)
            frame_count += 1
        cap.release()
        logging.info(f"Total frames extracted from {video_path}: {frame_count}")
    except Exception as e:
        logging.error(f"Error in split_video_to_frames: {e}")

# Function to perform blob detection
def detect_blobs(image, min_area=1000, max_area=3000, min_circularity=0.1, min_convexity=0.5, min_inertia_ratio=0.01):
    try:
        # Convert image to grayscale
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Apply Gaussian blur
        blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

        # Apply thresholding
        _, thresh_image = cv2.threshold(blurred_image, 60, 255, cv2.THRESH_BINARY_INV)

        # Set up the blob detector
        params = cv2.SimpleBlobDetector_Params()
        params.filterByArea = True
        params.minArea = min_area
        params.maxArea = max_area
        params.filterByCircularity = True
        params.minCircularity = min_circularity
        params.filterByConvexity = True
        params.minConvexity = min_convexity
        params.filterByInertia = True
        params.minInertiaRatio = min_inertia_ratio
        detector = cv2.SimpleBlobDetector_create(params)

        # Detect blobs
        keypoints = detector.detect(thresh_image)
        logging.info(f"Detected {len(keypoints)} blobs in the image")
        return keypoints
    except Exception as e:
        logging.error(f"Error in detect_blobs: {e}")
        return []

# Function to save blobs as images
def save_blobs_as_images(frame_path, keypoints, output_dir):
    try:
        image = cv2.imread(frame_path)
        for i, kp in enumerate(keypoints):
            x = int(kp.pt[0] - kp.size / 2)
            y = int(kp.pt[1] - kp.size / 2)
            w = int(kp.size)
            h = int(kp.size)
            blob_roi = image[y:y+h, x:x+w]
            if blob_roi.size > 0:
                blob_path = os.path.join(output_dir, f"{os.path.basename(frame_path).split('.')[0]}_blob_{i:02d}.jpg")
                cv2.imwrite(blob_path, blob_roi)
                logging.info(f"Saved blob {i} to {blob_path}")
    except Exception as e:
        logging.error(f"Error in save_blobs_as_images: {e}")

# Function to automatically label blobs
def label_blobs_automatically(blob_dir, label_output_file):
    try:
        labels = []
        for file_name in os.listdir(blob_dir):
            if file_name.endswith(".jpg"):
                blob_path = os.path.join(blob_dir, file_name)
                blob = cv2.imread(blob_path)
                height, width, _ = blob.shape

                # Detect keypoints in the blob image itself to check detection
                keypoints = detect_blobs(blob)
                if not keypoints:
                    logging.warning(f"No keypoints detected in {blob_path}")

                for kp in keypoints:
                    center_x = kp.pt[0]
                    
                    # Simple criteria for labeling
                    if center_x < width / 3:
                        label = "Left"
                    elif center_x > 2 * width / 3:
                        label = "Right"
                    else:
                        label = "Center"

                    labels.append((file_name, label))
                    logging.info(f"Labeled blob in {file_name} as {label}")

        with open(label_output_file, 'w') as f:
            for file_name, label in labels:
                f.write(f"{file_name},{label}\n")
        logging.info(f"Labels saved to {label_output_file}")
    except Exception as e:
        logging.error(f"Error in label_blobs_automatically: {e}")

def main():
    # Paths
    video_path_1 = "/Users/ayushpuri/Desktop/DRC TEAM 1/video4.avi"
    video_path_2 = "/Users/ayushpuri/Desktop/DRC TEAM 1/video5.avi"
    frames_output_dir = "/Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Frames"
    blobs_output_dir = "/Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs"

    # Create output directories if they don't exist
    os.makedirs(frames_output_dir, exist_ok=True)
    os.makedirs(blobs_output_dir, exist_ok=True)

    # Split videos into frames
    split_video_to_frames(video_path_1, frames_output_dir)
    split_video_to_frames(video_path_2, frames_output_dir)

    # Process each frame for blob detection and save blobs
    def process_frame(frame_file):
        frame_path = os.path.join(frames_output_dir, frame_file)
        frame_image = cv2.imread(frame_path)
        keypoints = detect_blobs(frame_image)
        save_blobs_as_images(frame_path, keypoints, blobs_output_dir)

    with ThreadPoolExecutor() as executor:
        executor.map(process_frame, os.listdir(frames_output_dir))

    # Automatically label blobs
    label_output_file = '/Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/blob_labels.csv'
    label_blobs_automatically(blobs_output_dir, label_output_file)

    logging.info("Processing completed.")

if __name__ == "__main__":
    main()
# Out:
# 2024-07-09 12:45:17,020 - INFO - Total frames extracted from /Users/ayushpuri/Desktop/DRC TEAM 1/video4.avi: 1877
# 2024-07-09 12:45:19,753 - INFO - Total frames extracted from /Users/ayushpuri/Desktop/DRC TEAM 1/video5.avi: 1251
# 2024-07-09 12:45:19,871 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,873 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,874 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,876 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,878 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,878 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,881 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,881 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,882 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,883 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,887 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0955_blob_00.jpg
# 2024-07-09 12:45:19,887 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,891 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,891 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1493_blob_00.jpg
# 2024-07-09 12:45:19,891 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0941_blob_00.jpg
# 2024-07-09 12:45:19,895 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1487_blob_00.jpg
# 2024-07-09 12:45:19,896 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1322_blob_00.jpg
# 2024-07-09 12:45:19,907 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0969_blob_00.jpg
# 2024-07-09 12:45:19,910 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0028_blob_00.jpg
# 2024-07-09 12:45:19,916 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0799_blob_00.jpg
# 2024-07-09 12:45:19,917 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0996_blob_00.jpg
# 2024-07-09 12:45:19,917 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1444_blob_00.jpg
# 2024-07-09 12:45:19,923 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1450_blob_00.jpg
# 2024-07-09 12:45:19,925 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1336_blob_00.jpg
# 2024-07-09 12:45:19,931 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,940 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,946 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,948 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:19,948 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,954 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:19,964 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,968 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:19,972 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,974 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,976 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,977 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1478_blob_00.jpg
# 2024-07-09 12:45:19,980 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1691_blob_00.jpg
# 2024-07-09 12:45:19,981 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1685_blob_00.jpg
# 2024-07-09 12:45:19,984 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1134_blob_00.jpg
# 2024-07-09 12:45:19,984 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:19,986 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1861_blob_00.jpg
# 2024-07-09 12:45:20,022 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1875_blob_00.jpg
# 2024-07-09 12:45:19,990 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1685_blob_01.jpg
# 2024-07-09 12:45:20,016 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1849_blob_00.jpg
# 2024-07-09 12:45:20,017 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,020 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,036 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0982_blob_00.jpg
# 2024-07-09 12:45:20,036 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1652_blob_00.jpg
# 2024-07-09 12:45:19,989 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1478_blob_01.jpg
# 2024-07-09 12:45:20,041 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1646_blob_00.jpg
# 2024-07-09 12:45:20,068 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1646_blob_01.jpg
# 2024-07-09 12:45:20,057 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,083 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0570_blob_00.jpg
# 2024-07-09 12:45:20,085 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,076 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0772_blob_00.jpg
# 2024-07-09 12:45:20,048 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,084 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:20,069 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,095 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,096 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,106 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,106 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1083_blob_00.jpg
# 2024-07-09 12:45:20,115 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0000_blob_00.jpg
# 2024-07-09 12:45:20,116 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0216_blob_00.jpg
# 2024-07-09 12:45:20,121 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,122 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0202_blob_00.jpg
# 2024-07-09 12:45:20,124 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1120_blob_00.jpg
# 2024-07-09 12:45:20,130 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0389_blob_00.jpg
# 2024-07-09 12:45:20,130 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0564_blob_00.jpg
# 2024-07-09 12:45:20,136 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,147 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1097_blob_00.jpg
# 2024-07-09 12:45:20,177 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,184 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0766_blob_00.jpg
# 2024-07-09 12:45:20,186 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,199 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0389_blob_01.jpg
# 2024-07-09 12:45:20,200 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,206 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,211 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,211 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1040_blob_00.jpg
# 2024-07-09 12:45:20,225 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,231 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0766_blob_01.jpg
# 2024-07-09 12:45:20,231 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0014_blob_00.jpg
# 2024-07-09 12:45:20,231 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1726_blob_00.jpg
# 2024-07-09 12:45:20,238 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0438_blob_00.jpg
# 2024-07-09 12:45:20,243 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1732_blob_00.jpg
# 2024-07-09 12:45:20,245 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,245 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1054_blob_00.jpg
# 2024-07-09 12:45:20,251 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0362_blob_00.jpg
# 2024-07-09 12:45:20,255 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0404_blob_00.jpg
# 2024-07-09 12:45:20,256 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,266 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,274 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,312 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,279 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,282 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0410_blob_00.jpg
# 2024-07-09 12:45:20,283 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,295 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,301 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,309 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1068_blob_00.jpg
# 2024-07-09 12:45:20,332 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1295_blob_00.jpg
# 2024-07-09 12:45:20,278 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,318 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0821_blob_00.jpg
# 2024-07-09 12:45:20,320 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0376_blob_00.jpg
# 2024-07-09 12:45:20,320 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,320 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1524_blob_00.jpg
# 2024-07-09 12:45:20,323 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0410_blob_01.jpg
# 2024-07-09 12:45:20,324 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1281_blob_00.jpg
# 2024-07-09 12:45:20,311 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:20,334 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0809_blob_00.jpg
# 2024-07-09 12:45:20,335 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0558_blob_00.jpg
# 2024-07-09 12:45:20,343 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0835_blob_00.jpg
# 2024-07-09 12:45:20,345 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0376_blob_01.jpg
# 2024-07-09 12:45:20,354 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0148_blob_00.jpg
# 2024-07-09 12:45:20,364 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,364 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,371 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,372 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,387 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,389 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,393 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,394 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,397 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,400 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0148_blob_01.jpg
# 2024-07-09 12:45:20,408 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1256_blob_00.jpg
# 2024-07-09 12:45:20,414 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1530_blob_00.jpg
# 2024-07-09 12:45:20,417 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1518_blob_00.jpg
# 2024-07-09 12:45:20,419 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,419 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,424 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0606_blob_00.jpg
# 2024-07-09 12:45:20,426 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0160_blob_00.jpg
# 2024-07-09 12:45:20,431 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0174_blob_00.jpg
# 2024-07-09 12:45:20,437 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0612_blob_00.jpg
# 2024-07-09 12:45:20,441 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0613_blob_00.jpg
# 2024-07-09 12:45:20,449 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0175_blob_00.jpg
# 2024-07-09 12:45:20,473 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0607_blob_00.jpg
# 2024-07-09 12:45:20,483 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,485 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1519_blob_00.jpg
# 2024-07-09 12:45:20,491 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,492 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,493 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0174_blob_01.jpg
# 2024-07-09 12:45:20,495 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,509 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0175_blob_01.jpg
# 2024-07-09 12:45:20,515 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,515 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:20,523 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0161_blob_00.jpg
# 2024-07-09 12:45:20,526 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,532 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0149_blob_00.jpg
# 2024-07-09 12:45:20,536 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1257_blob_00.jpg
# 2024-07-09 12:45:20,537 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,542 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,545 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1531_blob_00.jpg
# 2024-07-09 12:45:20,548 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,552 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1525_blob_00.jpg
# 2024-07-09 12:45:20,562 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0808_blob_00.jpg
# 2024-07-09 12:45:20,565 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0149_blob_01.jpg
# 2024-07-09 12:45:20,567 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,569 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1257_blob_01.jpg
# 2024-07-09 12:45:20,571 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,574 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1531_blob_01.jpg
# 2024-07-09 12:45:20,575 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,575 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0834_blob_00.jpg
# 2024-07-09 12:45:20,577 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1294_blob_00.jpg
# 2024-07-09 12:45:20,580 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,581 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1525_blob_01.jpg
# 2024-07-09 12:45:20,583 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0820_blob_00.jpg
# 2024-07-09 12:45:20,593 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0377_blob_00.jpg
# 2024-07-09 12:45:20,599 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,601 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0411_blob_00.jpg
# 2024-07-09 12:45:20,607 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1280_blob_00.jpg
# 2024-07-09 12:45:20,611 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,615 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1069_blob_00.jpg
# 2024-07-09 12:45:20,624 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,625 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,625 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,629 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,630 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0411_blob_01.jpg
# 2024-07-09 12:45:20,632 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0363_blob_00.jpg
# 2024-07-09 12:45:20,637 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,642 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0405_blob_00.jpg
# 2024-07-09 12:45:20,642 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,647 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,649 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1727_blob_00.jpg
# 2024-07-09 12:45:20,651 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1733_blob_00.jpg
# 2024-07-09 12:45:20,653 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,657 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1055_blob_00.jpg
# 2024-07-09 12:45:20,659 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,659 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1041_blob_00.jpg
# 2024-07-09 12:45:20,665 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0405_blob_01.jpg
# 2024-07-09 12:45:20,670 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0388_blob_00.jpg
# 2024-07-09 12:45:20,672 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0439_blob_00.jpg
# 2024-07-09 12:45:20,674 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1096_blob_00.jpg
# 2024-07-09 12:45:20,680 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,680 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0565_blob_00.jpg
# 2024-07-09 12:45:20,685 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:20,687 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1082_blob_00.jpg
# 2024-07-09 12:45:20,689 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,694 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,697 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,704 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0203_blob_00.jpg
# 2024-07-09 12:45:20,705 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0565_blob_01.jpg
# 2024-07-09 12:45:20,709 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,710 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,712 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,714 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0217_blob_00.jpg
# 2024-07-09 12:45:20,718 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0571_blob_00.jpg
# 2024-07-09 12:45:20,720 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,720 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0559_blob_00.jpg
# 2024-07-09 12:45:20,721 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,729 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1121_blob_00.jpg
# 2024-07-09 12:45:20,729 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,730 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1135_blob_00.jpg
# 2024-07-09 12:45:20,735 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,736 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1647_blob_00.jpg
# 2024-07-09 12:45:20,744 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1653_blob_00.jpg
# 2024-07-09 12:45:20,744 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,749 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,750 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1860_blob_00.jpg
# 2024-07-09 12:45:20,753 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,755 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1684_blob_00.jpg
# 2024-07-09 12:45:20,760 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1874_blob_00.jpg
# 2024-07-09 12:45:20,761 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1647_blob_01.jpg
# 2024-07-09 12:45:20,762 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,764 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1653_blob_01.jpg
# 2024-07-09 12:45:20,766 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,767 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,770 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1690_blob_00.jpg
# 2024-07-09 12:45:20,771 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1848_blob_00.jpg
# 2024-07-09 12:45:20,772 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,775 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0001_blob_00.jpg
# 2024-07-09 12:45:20,780 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1479_blob_00.jpg
# 2024-07-09 12:45:20,791 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0767_blob_00.jpg
# 2024-07-09 12:45:20,791 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,792 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,794 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,796 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,799 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0773_blob_00.jpg
# 2024-07-09 12:45:20,803 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0015_blob_00.jpg
# 2024-07-09 12:45:20,804 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1479_blob_01.jpg
# 2024-07-09 12:45:20,807 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0767_blob_01.jpg
# 2024-07-09 12:45:20,809 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,812 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0997_blob_00.jpg
# 2024-07-09 12:45:20,814 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0983_blob_00.jpg
# 2024-07-09 12:45:20,817 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,818 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1445_blob_00.jpg
# 2024-07-09 12:45:20,822 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,823 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1323_blob_00.jpg
# 2024-07-09 12:45:20,824 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,844 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,846 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1451_blob_00.jpg
# 2024-07-09 12:45:20,848 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,852 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,854 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,857 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0029_blob_00.jpg
# 2024-07-09 12:45:20,916 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1337_blob_00.jpg
# 2024-07-09 12:45:20,918 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,926 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:20,929 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0968_blob_00.jpg
# 2024-07-09 12:45:20,930 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,934 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0798_blob_00.jpg
# 2024-07-09 12:45:20,938 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0940_blob_00.jpg
# 2024-07-09 12:45:20,938 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1486_blob_00.jpg
# 2024-07-09 12:45:20,942 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0954_blob_00.jpg
# 2024-07-09 12:45:20,952 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,958 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1492_blob_00.jpg
# 2024-07-09 12:45:20,958 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,968 - INFO - Detected 3 blobs in the image
# 2024-07-09 12:45:20,968 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1484_blob_00.jpg
# 2024-07-09 12:45:20,970 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0798_blob_01.jpg
# 2024-07-09 12:45:20,973 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0942_blob_00.jpg
# 2024-07-09 12:45:20,974 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,984 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1490_blob_00.jpg
# 2024-07-09 12:45:20,988 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:20,993 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0956_blob_00.jpg
# 2024-07-09 12:45:20,993 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1484_blob_01.jpg
# 2024-07-09 12:45:20,996 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0759_blob_00.jpg
# 2024-07-09 12:45:20,999 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,000 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,002 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,007 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,009 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1447_blob_00.jpg
# 2024-07-09 12:45:21,013 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0981_blob_00.jpg
# 2024-07-09 12:45:21,033 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,018 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0759_blob_01.jpg
# 2024-07-09 12:45:21,018 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,024 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1321_blob_00.jpg
# 2024-07-09 12:45:21,027 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1453_blob_00.jpg
# 2024-07-09 12:45:21,030 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0995_blob_00.jpg
# 2024-07-09 12:45:21,031 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,017 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,033 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,035 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1335_blob_00.jpg
# 2024-07-09 12:45:21,061 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0017_blob_00.jpg
# 2024-07-09 12:45:21,044 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0003_blob_00.jpg
# 2024-07-09 12:45:21,045 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,058 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0765_blob_00.jpg
# 2024-07-09 12:45:21,060 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1309_blob_00.jpg
# 2024-07-09 12:45:21,061 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,040 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0771_blob_00.jpg
# 2024-07-09 12:45:21,062 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,068 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,069 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,069 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,072 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0765_blob_01.jpg
# 2024-07-09 12:45:21,075 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0598_blob_00.jpg
# 2024-07-09 12:45:21,094 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,094 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1692_blob_00.jpg
# 2024-07-09 12:45:21,096 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,099 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,107 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,108 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1876_blob_00.jpg
# 2024-07-09 12:45:21,111 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1686_blob_00.jpg
# 2024-07-09 12:45:21,112 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1862_blob_00.jpg
# 2024-07-09 12:45:21,117 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1123_blob_00.jpg
# 2024-07-09 12:45:21,120 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,132 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1645_blob_00.jpg
# 2024-07-09 12:45:21,140 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1651_blob_00.jpg
# 2024-07-09 12:45:21,142 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,144 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0229_blob_00.jpg
# 2024-07-09 12:45:21,145 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1137_blob_00.jpg
# 2024-07-09 12:45:21,149 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,158 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0201_blob_00.jpg
# 2024-07-09 12:45:21,158 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,162 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1645_blob_01.jpg
# 2024-07-09 12:45:21,164 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,167 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,174 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,176 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,183 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,187 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1679_blob_00.jpg
# 2024-07-09 12:45:21,190 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0215_blob_00.jpg
# 2024-07-09 12:45:21,195 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,198 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,198 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1094_blob_00.jpg
# 2024-07-09 12:45:21,200 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1057_blob_00.jpg
# 2024-07-09 12:45:21,200 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1080_blob_00.jpg
# 2024-07-09 12:45:21,201 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,204 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0349_blob_00.jpg
# 2024-07-09 12:45:21,209 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1731_blob_00.jpg
# 2024-07-09 12:45:21,211 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1725_blob_00.jpg
# 2024-07-09 12:45:21,221 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1043_blob_00.jpg
# 2024-07-09 12:45:21,233 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,241 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,243 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1719_blob_00.jpg
# 2024-07-09 12:45:21,247 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,249 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0188_blob_00.jpg
# 2024-07-09 12:45:21,253 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,254 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1296_blob_00.jpg
# 2024-07-09 12:45:21,262 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1282_blob_00.jpg
# 2024-07-09 12:45:21,270 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,272 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0567_blob_00.jpg
# 2024-07-09 12:45:21,276 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0567_blob_01.jpg
# 2024-07-09 12:45:21,279 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1533_blob_00.jpg
# 2024-07-09 12:45:21,280 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:21,280 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,301 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,302 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,310 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1255_blob_00.jpg
# 2024-07-09 12:45:21,315 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0639_blob_00.jpg
# 2024-07-09 12:45:21,303 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,323 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1527_blob_00.jpg
# 2024-07-09 12:45:21,325 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0573_blob_00.jpg
# 2024-07-09 12:45:21,339 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,345 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,354 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0611_blob_00.jpg
# 2024-07-09 12:45:21,362 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,369 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0163_blob_00.jpg
# 2024-07-09 12:45:21,369 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0177_blob_00.jpg
# 2024-07-09 12:45:21,371 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,389 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,384 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0605_blob_00.jpg
# 2024-07-09 12:45:21,387 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0177_blob_01.jpg
# 2024-07-09 12:45:21,391 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,374 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,391 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,395 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0162_blob_00.jpg
# 2024-07-09 12:45:21,397 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0610_blob_00.jpg
# 2024-07-09 12:45:21,410 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0604_blob_00.jpg
# 2024-07-09 12:45:21,414 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1269_blob_00.jpg
# 2024-07-09 12:45:21,420 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,423 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0375_blob_00.jpg
# 2024-07-09 12:45:21,427 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,438 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1269_blob_01.jpg
# 2024-07-09 12:45:21,439 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,444 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:21,450 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,451 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0176_blob_00.jpg
# 2024-07-09 12:45:21,456 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,457 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1268_blob_00.jpg
# 2024-07-09 12:45:21,463 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,463 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0413_blob_00.jpg
# 2024-07-09 12:45:21,471 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0176_blob_01.jpg
# 2024-07-09 12:45:21,491 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1532_blob_00.jpg
# 2024-07-09 12:45:21,479 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1526_blob_00.jpg
# 2024-07-09 12:45:21,484 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1268_blob_01.jpg
# 2024-07-09 12:45:21,476 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0638_blob_00.jpg
# 2024-07-09 12:45:21,496 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,504 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,508 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,512 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,529 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,530 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,531 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0407_blob_00.jpg
# 2024-07-09 12:45:21,547 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,538 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,539 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1254_blob_00.jpg
# 2024-07-09 12:45:21,539 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0823_blob_00.jpg
# 2024-07-09 12:45:21,562 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0361_blob_00.jpg
# 2024-07-09 12:45:21,548 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0837_blob_00.jpg
# 2024-07-09 12:45:21,549 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0189_blob_00.jpg
# 2024-07-09 12:45:21,592 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,564 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,535 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,578 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,589 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,589 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0406_blob_00.jpg
# 2024-07-09 12:45:21,593 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,550 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1297_blob_00.jpg
# 2024-07-09 12:45:21,596 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,601 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0836_blob_00.jpg
# 2024-07-09 12:45:21,604 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,610 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0360_blob_00.jpg
# 2024-07-09 12:45:21,625 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1718_blob_00.jpg
# 2024-07-09 12:45:21,627 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1724_blob_00.jpg
# 2024-07-09 12:45:21,627 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1283_blob_00.jpg
# 2024-07-09 12:45:21,634 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0374_blob_00.jpg
# 2024-07-09 12:45:21,644 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0412_blob_00.jpg
# 2024-07-09 12:45:21,646 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,646 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,651 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1042_blob_00.jpg
# 2024-07-09 12:45:21,659 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,665 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,675 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0822_blob_00.jpg
# 2024-07-09 12:45:21,675 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,675 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,688 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0348_blob_00.jpg
# 2024-07-09 12:45:21,690 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,692 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,695 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,696 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,697 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1081_blob_00.jpg
# 2024-07-09 12:45:21,699 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,704 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1095_blob_00.jpg
# 2024-07-09 12:45:21,705 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,707 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0214_blob_00.jpg
# 2024-07-09 12:45:21,712 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0572_blob_00.jpg
# 2024-07-09 12:45:21,719 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,721 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0200_blob_00.jpg
# 2024-07-09 12:45:21,721 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1056_blob_00.jpg
# 2024-07-09 12:45:21,733 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1678_blob_00.jpg
# 2024-07-09 12:45:21,733 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1730_blob_00.jpg
# 2024-07-09 12:45:21,736 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,756 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1650_blob_00.jpg
# 2024-07-09 12:45:21,770 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,788 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0566_blob_00.jpg
# 2024-07-09 12:45:21,790 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,792 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0572_blob_01.jpg
# 2024-07-09 12:45:21,801 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1136_blob_00.jpg
# 2024-07-09 12:45:21,815 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0228_blob_00.jpg
# 2024-07-09 12:45:21,818 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,821 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,824 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,829 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0566_blob_01.jpg
# 2024-07-09 12:45:21,831 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1122_blob_00.jpg
# 2024-07-09 12:45:21,832 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,833 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,834 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1644_blob_00.jpg
# 2024-07-09 12:45:21,848 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1863_blob_00.jpg
# 2024-07-09 12:45:21,852 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,852 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,856 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1693_blob_00.jpg
# 2024-07-09 12:45:21,857 - INFO - Detected 3 blobs in the image
# 2024-07-09 12:45:21,860 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,867 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1644_blob_01.jpg
# 2024-07-09 12:45:21,868 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1687_blob_00.jpg
# 2024-07-09 12:45:21,883 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1308_blob_00.jpg
# 2024-07-09 12:45:21,886 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,896 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,915 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1334_blob_00.jpg
# 2024-07-09 12:45:21,918 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:21,940 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1452_blob_00.jpg
# 2024-07-09 12:45:21,946 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1446_blob_00.jpg
# 2024-07-09 12:45:21,950 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,952 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1446_blob_01.jpg
# 2024-07-09 12:45:21,960 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1320_blob_00.jpg
# 2024-07-09 12:45:21,954 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0599_blob_00.jpg
# 2024-07-09 12:45:21,978 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,986 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0599_blob_01.jpg
# 2024-07-09 12:45:21,995 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:21,996 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:22,002 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1491_blob_00.jpg
# 2024-07-09 12:45:22,008 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0943_blob_00.jpg
# 2024-07-09 12:45:22,015 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1485_blob_00.jpg
# 2024-07-09 12:45:22,019 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,027 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,030 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1485_blob_01.jpg
# 2024-07-09 12:45:22,045 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0994_blob_00.jpg
# 2024-07-09 12:45:22,051 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0016_blob_00.jpg
# 2024-07-09 12:45:22,052 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0947_blob_00.jpg
# 2024-07-09 12:45:22,059 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,069 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:22,086 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,091 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,096 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0953_blob_00.jpg
# 2024-07-09 12:45:22,106 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1481_blob_00.jpg
# 2024-07-09 12:45:22,114 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0770_blob_00.jpg
# 2024-07-09 12:45:22,115 - INFO - Detected 3 blobs in the image
# 2024-07-09 12:45:22,115 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:22,127 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1495_blob_00.jpg
# ...
# 2024-07-09 12:45:28,305 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1634_blob_00.jpg
# 2024-07-09 12:45:28,305 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1608_blob_00.jpg
# 2024-07-09 12:45:28,308 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,308 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0258_blob_00.jpg
# 2024-07-09 12:45:28,312 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1146_blob_00.jpg
# 2024-07-09 12:45:28,314 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1152_blob_01.jpg
# 2024-07-09 12:45:28,321 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0489_blob_00.jpg
# 2024-07-09 12:45:28,325 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1783_blob_00.jpg
# 2024-07-09 12:45:28,326 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,327 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,328 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1634_blob_01.jpg
# 2024-07-09 12:45:28,328 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,334 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1797_blob_00.jpg
# 2024-07-09 12:45:28,355 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,356 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,361 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,364 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,367 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0304_blob_00.jpg
# 2024-07-09 12:45:28,368 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,370 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0462_blob_00.jpg
# 2024-07-09 12:45:28,374 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0476_blob_00.jpg
# 2024-07-09 12:45:28,375 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,379 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,379 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0310_blob_00.jpg
# 2024-07-09 12:45:28,382 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1768_blob_00.jpg
# 2024-07-09 12:45:28,386 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1026_blob_00.jpg
# 2024-07-09 12:45:28,387 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0338_blob_00.jpg
# 2024-07-09 12:45:28,389 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,392 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1740_blob_00.jpg
# 2024-07-09 12:45:28,395 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,397 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1754_blob_00.jpg
# 2024-07-09 12:45:28,399 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1032_blob_00.jpg
# 2024-07-09 12:45:28,407 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,408 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,409 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,415 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1581_blob_00.jpg
# 2024-07-09 12:45:28,416 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0847_blob_00.jpg
# 2024-07-09 12:45:28,417 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,417 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,425 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,425 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,491 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0106_blob_00.jpg
# 2024-07-09 12:45:28,476 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,466 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1595_blob_00.jpg
# 2024-07-09 12:45:28,479 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0660_blob_00.jpg
# 2024-07-09 12:45:28,481 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,482 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,483 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0847_blob_01.jpg
# 2024-07-09 12:45:28,427 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0853_blob_00.jpg
# 2024-07-09 12:45:28,492 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0674_blob_00.jpg
# 2024-07-09 12:45:28,497 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0112_blob_00.jpg
# 2024-07-09 12:45:28,499 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0884_blob_00.jpg
# 2024-07-09 12:45:28,500 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1595_blob_01.jpg
# 2024-07-09 12:45:28,501 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,512 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,517 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1542_blob_00.jpg
# 2024-07-09 12:45:28,551 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,523 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,525 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,543 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,546 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,551 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0890_blob_00.jpg
# 2024-07-09 12:45:28,552 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1542_blob_01.jpg
# 2024-07-09 12:45:28,521 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,552 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,554 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,555 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,558 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0891_blob_00.jpg
# 2024-07-09 12:45:28,562 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1556_blob_00.jpg
# 2024-07-09 12:45:28,564 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0885_blob_00.jpg
# 2024-07-09 12:45:28,565 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,566 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0649_blob_00.jpg
# 2024-07-09 12:45:28,574 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0648_blob_00.jpg
# 2024-07-09 12:45:28,576 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1543_blob_00.jpg
# 2024-07-09 12:45:28,580 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1557_blob_00.jpg
# 2024-07-09 12:45:28,581 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1556_blob_01.jpg
# 2024-07-09 12:45:28,581 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,582 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,587 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0113_blob_00.jpg
# 2024-07-09 12:45:28,587 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,590 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0648_blob_01.jpg
# 2024-07-09 12:45:28,592 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1557_blob_01.jpg
# 2024-07-09 12:45:28,592 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1543_blob_01.jpg
# 2024-07-09 12:45:28,599 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0675_blob_00.jpg
# 2024-07-09 12:45:28,634 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,634 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,637 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,641 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,643 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0661_blob_00.jpg
# 2024-07-09 12:45:28,648 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,660 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0852_blob_00.jpg
# 2024-07-09 12:45:28,665 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0107_blob_00.jpg
# 2024-07-09 12:45:28,667 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,668 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,668 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,669 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,673 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,674 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0846_blob_00.jpg
# 2024-07-09 12:45:28,678 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1594_blob_00.jpg
# 2024-07-09 12:45:28,679 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,681 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1580_blob_00.jpg
# 2024-07-09 12:45:28,686 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0339_blob_00.jpg
# 2024-07-09 12:45:28,687 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1033_blob_00.jpg
# 2024-07-09 12:45:28,691 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1027_blob_00.jpg
# 2024-07-09 12:45:28,693 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,693 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1755_blob_00.jpg
# 2024-07-09 12:45:28,697 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,699 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1741_blob_00.jpg
# 2024-07-09 12:45:28,699 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1594_blob_01.jpg
# 2024-07-09 12:45:28,701 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1580_blob_01.jpg
# 2024-07-09 12:45:28,705 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1769_blob_00.jpg
# 2024-07-09 12:45:28,705 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,722 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,728 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0477_blob_00.jpg
# 2024-07-09 12:45:28,730 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,733 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0311_blob_00.jpg
# 2024-07-09 12:45:28,735 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,763 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,781 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,781 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0305_blob_00.jpg
# 2024-07-09 12:45:28,801 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1782_blob_00.jpg
# 2024-07-09 12:45:28,788 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,793 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,793 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,811 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1621_blob_00.jpg
# 2024-07-09 12:45:28,799 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1796_blob_00.jpg
# 2024-07-09 12:45:28,787 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0463_blob_00.jpg
# 2024-07-09 12:45:28,820 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0463_blob_01.jpg
# 2024-07-09 12:45:28,804 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1147_blob_00.jpg
# 2024-07-09 12:45:28,807 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,798 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0488_blob_00.jpg
# 2024-07-09 12:45:28,813 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0259_blob_00.jpg
# 2024-07-09 12:45:28,815 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1153_blob_00.jpg
# 2024-07-09 12:45:28,839 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1153_blob_01.jpg
# 2024-07-09 12:45:28,827 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,802 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,832 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,834 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,836 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0488_blob_01.jpg
# 2024-07-09 12:45:28,824 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,842 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,844 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1635_blob_00.jpg
# 2024-07-09 12:45:28,848 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,849 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0271_blob_00.jpg
# 2024-07-09 12:45:28,854 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0503_blob_00.jpg
# 2024-07-09 12:45:28,855 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0517_blob_00.jpg
# 2024-07-09 12:45:28,862 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,864 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,865 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,870 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0265_blob_00.jpg
# 2024-07-09 12:45:28,871 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1190_blob_00.jpg
# 2024-07-09 12:45:28,873 - INFO - Saved blob 1 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1635_blob_01.jpg
# 2024-07-09 12:45:28,882 - INFO - Detected 0 blobs in the image
# 2024-07-09 12:45:28,885 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1609_blob_00.jpg
# 2024-07-09 12:45:28,901 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,903 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1806_blob_00.jpg
# 2024-07-09 12:45:28,934 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,937 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1812_blob_00.jpg
# 2024-07-09 12:45:28,949 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1345_blob_00.jpg
# 2024-07-09 12:45:28,951 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,955 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,960 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1437_blob_00.jpg
# 2024-07-09 12:45:28,966 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,967 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,968 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,974 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_0729_blob_00.jpg
# 2024-07-09 12:45:28,975 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,976 - INFO - Detected 2 blobs in the image
# 2024-07-09 12:45:28,979 - INFO - Detected 1 blobs in the image
# 2024-07-09 12:45:28,981 - INFO - Saved blob 0 to /Users/ayushpuri/Desktop/DRC TEAM 1/Dataset/Blobs/frame_1351_blob_00.jpg
# 2024-07-09 12:45:28,987 - INFO - Detected 1 blobs in the image
